# %% [markdown]
# # 1. Sgr A* Flares Spectrum
# __Some housekeeping__
# * Run this notebook in Python 3.
#
# The Sgr A* spectrum is given in figure 1. (Yuan et al. 2003)
#
# ![title](img/SpectrumYuan2003.PNG)
#
#
# __Goals of this notebook__
#
# * Create a seed distribution synchroton photons from a mildly relativistic electrons.
# * Perform (at least one) IC scatterings.
# * Put all of the machinery into the correct geometry, with the goal of reproducing the spectrum of flares in Sgr A* jets.
#
#
# First we do some necessary python imports.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import scipy.integrate as integrate
from scipy.integrate import quad
from scipy.special import kn

# %% [markdown]
# Next up, we make some functions that we will need to obtain the synchroton power spectrum (per electron) as a function of magnetic field, lorentz factor and pitch angle.

# %%
def freq_sync(gamma,B):
    f_s=gamma**2*B*2.65e6
    return(f_s)

def freq_crit(gamma,B,theta):
    f_c=3/2*freq_sync(gamma,B)*np.sin(theta)
    return(f_c)

def K_fivethird(x):
    y=kn(5/3,x)
    return(y)

def F_sync(f,f_c):
    x=f/f_c
    output_integral=integrate.quad(K_fivethird,x,np.inf)
    F=x*output_integral[0]
    return(F)

def P_sync(gamma,f,B,theta):
    P = 2.41e-22*B*np.sin(theta)*F_sync(f,freq_crit(gamma,B,theta))
    return(P)

# %% [markdown]
# And we test the function out.

# %%
f_min=10
f_max=13

f = np.logspace(f_min,f_max,1000)
P = np.zeros(1000)
gamma = 300
B=3
theta = np.pi/2
for i in range(len(f)):
    P[i] = P_sync(gamma,f[i],B,theta)

f_peak=0.3*freq_crit(gamma,B,theta)
print('according to peak frequency formula, the peak should be at {0:5.3e} or 10^{1:3.2f}'.format(f_peak,np.log10(f_peak)))

plt.plot(f,P, label='$P(f)$')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.title(r'Power per frequency',fontsize=20)
plt.xlabel(r'$\nu$[Hz]',fontsize=20)
plt.ylabel(r'P[erg/s/Hz]',fontsize=20)
plt.show()

plt.plot(f,P*f,label='f*P(f)')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.title(r'Power',fontsize=20)
plt.xlabel(r'$\nu$[Hz]',fontsize=20)
plt.ylabel(r'$\nu$P[erg/s]',fontsize=20)
plt.show()
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: floating point number truncated to an integer
#   # Remove the CWD from sys.path while we load stuff.
# according to peak frequency formula, the peak should be at 3.220e+11 or 10^11.51

# %% [markdown]
# Next up, we want to find the emissivity as a function of magnetic field $B$ and the angle between velocity and field $\theta$. This is integrated from $\gamma_{min}$ to $\gamma_{max}$

# %%
def Emissivity_powerlaw(p,gamma_min,gamma_max,f,B,theta):
    def N_powerlaw(gamma):
        N = gamma**-p
        return(N)
    def P_1argument(gamma):
        P=P_sync(gamma,f,B,theta)
        return(P)
    def NstarP(gamma):
        N_P=N_powerlaw(gamma)*P_1argument(gamma)
        return(N_P)
    output_integral=integrate.quad(NstarP,gamma_min,gamma_max)
    E=1/(4*np.pi)*output_integral[0]
    return(E)

# %% [markdown]
# Some constants

# %%
m_e=1; #electron mass [units]
k=1;   #boltzmann constnat [units]
c=1;   #speed of light [units]

# %% [markdown]
# Now we want to test this out:

# %%
p=2.2
f_min=10
f_max=13
gamma_min=1
gamma_max=300
f=np.logspace(f_min,f_max,100)
B=3
theta=np.pi/2
E=np.zeros(len(f))


for i in range(len(f)):
    E[i]=Emissivity_powerlaw(p,gamma_min,gamma_max,f[i],B,theta)
    
plt.plot(f,E, label='$E(f)$')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.title(r'Emissivity per frequency',fontsize=20)
plt.xlabel(r'$\nu$[Hz]',fontsize=20)
plt.ylabel(r'E[erg/s/Volume[missing]/Hz]',fontsize=20)
plt.show()

plt.plot(f,f*E, label='$f*E(f)$')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.title(r'Emissivity',fontsize=20)
plt.xlabel(r'$\nu$[Hz]',fontsize=20)
plt.ylabel(r'$\nu$E[erg/s/Volume[missing]]',fontsize=20)
plt.show()
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: floating point number truncated to an integer
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# We will use this function to spawn photons with the right frequency distribution from electrons with a given $\gamma$.

# %%
x=np.linspace(0,5,100)
F=np.zeros(len(x))
for i in range(len(x)):
    F[i]=F_sync(x[i],1)

plt.plot(x,F)

def F_1input(x):
    F=F_sync(x,1)
    return(F)

total_chance=integrate.quad(F_1input,0,np.inf)
print(total_chance)
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: floating point number truncated to an integer
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   from ipykernel import kernelapp as app
# (1.0000000003201495, 7.1484352788306915e-09)

# %% [markdown]
# # Maxwell-Jüttner distribution of electrons
# The velocity distribution of electrons that will produce the synchroton radiation is that of mildly relativistic electrons: $kT \sim m_e c^2$.
# $$
#         f(\gamma)=\frac{\gamma^2\beta}{\theta K_2(1/\theta)}\text{exp}(-\frac{\gamma}{\theta}),
# $$
# where $\theta = \frac{kT}{m_e c^2}$, and $K_2$ is the modified Bessel function of the second kind.

# %%
gamma = np.linspace(1,100,1000)
beta=np.sqrt(1-1/gamma**2)
theta=10 # electron thermal energy in fractions of electron mass.

f=gamma**2*beta*np.exp(-gamma/theta)/(theta*kn(2,1/theta))

plt.loglog(gamma,f)
plt.xlabel('$\gamma$',fontsize=20)
plt.ylabel('f($\gamma$)', fontsize=20)
# Out:
# Text(0, 0.5, 'f($\\gamma$)')

# %%
# Out:
# Text(0, 0.5, 'f($\\gamma$)')

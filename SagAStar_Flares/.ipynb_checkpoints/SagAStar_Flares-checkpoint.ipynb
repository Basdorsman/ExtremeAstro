# %% [markdown]
# The Sgr A* spectrum is given in figure 1. (Yuan et al. 2003)
#
# ![title](img/SpectrumYuan2003.PNG)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import scipy.integrate as integrate
from scipy.integrate import quad
from scipy.special import kn


def freq_sync(gamma,B):
    f_s=gamma**2*B*2.65e6
    return(f_s)

def freq_crit(gamma,B,theta):
    f_c=3/2*freq_sync(gamma,B)*np.sin(theta)
    return(f_c)

def K_fivethird(x):
    y=kn(5/3,x)
    return(y)

def F_sync(f,f_c):
    x=f/f_c
    value=integrate.quad(K_fivethird,x,np.inf)
    F=x*value[0]
    return(F)




x = np.logspace(-2, 1, 1000)
N=5/3
F=np.zeros(len(x))

for i in range(len(x)):
    F[i]=F_sync(x[i],1)
    



plt.plot(x,F, label='$F(x)$')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.title(r'Integral of modified Bessel fucntion of the second kind $K_{5/3}(x)$')
plt.show()

# %%
def P_sync(f,gamma,B,theta):
    P = 2.41e-22*B*np.sin(theta)*F_sync(f,freq_crit(gamma,B,theta))
    return P

f = np.logspace(5,8.5,1000)
P = np.zeros(1000)
gamma = 3
B=1
theta = np.pi/2
for i in range(len(f)):
    P[i] = P_sync(f[i],gamma,B,theta)
    
plt.plot(f,P, label='$P(f)$')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.title(r'Power per frequency',fontsize=20)
plt.xlabel(r'$\nu$[Hz]',fontsize=20)
plt.ylabel(r'P[erg/s/Hz]',fontsize=20)
plt.show()

# %%
print(np.pi)
# Out:
# 3.14159265359
